# %% [markdown]
# <a href="https://colab.research.google.com/github/Grecia1225/2025-26-4090-Grecia-AI-B-DS/blob/main/21_04_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import (
    auc,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_curve,
)

# 1. Define data
y_true = [1, 0, 1, 0, 1, 0, 1, 0]
y_pred = [1, 1, 1, 0, 0, 0, 1, 0]
y_scores = [0.9, 0.6, 0.8, 0.3, 0.4, 0.2, 0.85, 0.1]

# 2. Calculate and print standard classification metrics
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)
print("Precision:", precision_score(y_true, y_pred))
print("Recall:", recall_score(y_true, y_pred))
print("F1 score:", f1_score(y_true, y_pred))

# 3. Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)
print("AUC:", roc_auc)

# 4. Plot the ROC Curve
plt.figure(figsize=(6, 5))
plt.plot(
    fpr, tpr, color="darkorange", lw=2, label=f"ROC curve (area = {roc_auc:.3f})"
)
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
# Out:
# Confusion Matrix:
#  [[3 1]
#  [1 3]]
# Precision: 0.75
# Recall: 0.75
# F1 score: 0.75
# AUC: 0.9375

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import svm

# 1. Define training data
# 2D features: [x1, x2]
X = [[2, 2], [4, 4], [2, 1], [0, 2]]
Y = [1, 1, -1, -1]  # Labels

# 2. Initialize and train the Support Vector Machine (SVM)
model = svm.SVC(kernel="linear")
model.fit(X, Y)

# 3. Predict the label for an unknown data point [0,0]
test_point = [[0, 0]]
prediction = model.predict(test_point)
print(f"Prediction for {test_point[0]}: {prediction[0]}")

# 4. Optional: Print the structural elements of the trained SVM
print("Support vectors:\n", model.support_vectors_)
print("Coefficients (w):\n", model.coef_)
print("Intercept (b):\n", model.intercept_)
# Out:
# Prediction for [0, 0]: -1
# Support vectors:
#  [[2. 1.]
#  [0. 2.]
#  [2. 2.]]
# Coefficients (w):
#  [[0.4 0.8]]
# Intercept (b):
#  [-2.6]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
X = np.array([1,2,3,4]).reshape(-1,1)
Y = np.array([1,4,9,16])
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, Y)
Y_pred = model.predict(X_poly)
plt.scatter(X, Y)
plt.plot(X, Y_pred)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
X = [[1,1], [1,0], [0,1], [0,0]]
y = [0,1,1,0]
model = DecisionTreeClassifier()
model.fit(X, y)
print(model.predict([[1,0]]))
# Out:
# [1]

# %%
from sklearn.tree import DecisionTreeClassifier
X = [[1,1,1], [1,0,1], [0,1,0], [0,0,0]]
y = [1,1,0,0]
model = DecisionTreeClassifier()
model.fit(X, y)
p = model.predict([[1,0,1]])
print("Prediction:", p)
# Out:
# Prediction: [1]
