# %% [markdown]
# <a href="https://colab.research.google.com/github/Grecia1225/2025-26-4090-Grecia-AI-B-DS/blob/main/01_06_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
G=nx.Graph()
G.add_edges_from([
    ('A','B'),
    ('B','C'),
    ('B','D')
])
print(nx.degree_centrality(G))
print(nx.betweenness_centrality(G))
print(nx.closeness_centrality(G))
# Out:
# {'A': 0.3333333333333333, 'B': 1.0, 'C': 0.3333333333333333, 'D': 0.3333333333333333}
# {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# {'A': 0.6, 'B': 1.0, 'C': 0.6, 'D': 0.6}

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edges_from([
    ('A','B'),
    ('A','C'),
    ('B','D'),
    ('C','D'),
    ('E','F'),    ('E','G'),     ('F','H'),     ('G','H'),     ('D','E')  ])

from networkx.algorithms.community import greedy_modularity_communities

communities = greedy_modularity_communities(G)

for i, com in enumerate(communities):
    print(f"Community {i+1}: {list(com)}")

nx.draw(G, with_labels=True, node_size=3000)
plt.show()
Community1: ['A', 'B', 'C', 'D']

Community2: ['E', 'F', 'G', 'H']
# Out:
# Community 1: ['A', 'D', 'C', 'B']
# Community 2: ['F', 'E', 'H', 'G']

# %%
import networkx as nx
G=nx.Graph()
G.add_edges_from([
    ('A','B'),
    ('B','C'),
    ('B','D')
])
print(nx.degree_centrality(G))
print(nx.betweenness_centrality(G))
print(nx.closeness_centrality(G))
# Out:
# {'A': 0.3333333333333333, 'B': 1.0, 'C': 0.3333333333333333, 'D': 0.3333333333333333}
# {'A': 0.0, 'B': 1.0, 'C': 0.0, 'D': 0.0}
# {'A': 0.6, 'B': 1.0, 'C': 0.6, 'D': 0.6}

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edges_from([
    ('A','B'),
    ('A','C'),
    ('B','D'),
    ('C','D'),
    ('E','F'),    ('E','G'),     ('F','H'),     ('G','H'),     ('D','E')  ])

from networkx.algorithms.community import greedy_modularity_communities

communities = greedy_modularity_communities(G)

for i, com in enumerate(communities):
    print(f"Community {i+1}: {list(com)}")

nx.draw(G, with_labels=True, node_size=3000)
plt.show()
Community1: ['A', 'B', 'C', 'D']

Community2: ['E', 'F', 'G', 'H']
# Out:
# Community 1: ['A', 'D', 'C', 'B']
# Community 2: ['F', 'E', 'H', 'G']

# %%
import networkx as nx
G=nx.DiGraph()
G.add_edges_from([
    ('A','B'),
    ('A','C'),
    ('B','C'),
    ('D','C'),
    ('E','B'),
    ('E','C')

])
page_rank=nx.pagerank(G,alpha=0.85)
print("Page Rank Scores:")
for page,rank in page_rank.items():
  print(f"{page}:{rank:4f}")
# Out:
# Page Rank Scores:
# A:0.109619
# B:0.202795
# C:0.468348
# D:0.109619
# E:0.109619
